# %% [markdown]
# <h3>Import libraries required to complete task</h3>

# %%
import csv
import pandas as pd
import numpy as np
#import geocoder

# %% [markdown]
# <h3>Read Toronto_Geospatial_Coordinates.csv into Pandas DataFrame.</h3>

# %%
#Tronto_GeoData_File = open('Toronto_Geospatial_Coordinates.csv')
#Tronto_GeoData_Reader = csv.reader(Tronto_GeoData_File)
#Tronto_GeoData = list(Tronto_GeoData_Reader)
#Tronto_GeoData[0:5]

Tronto_GeoData_File = pd.read_csv('Toronto_Geospatial_Coordinates.csv')
Tronto_GeoData_File[0:5]
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %% [markdown]
# <h3>Import Tronto neighborhood dataset from week3 part1 using read_pickle</h3>

# %%
Tron_neighborhoods = pd.read_pickle("Tron_neighborhoods_Dataset.pkl")
Tron_neighborhoods[:5]
# Out:
#   PostalCode           Borough                      Neighborhood
# 0        M3A        North York                         Parkwoods
# 1        M4A        North York                  Victoria Village
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront
# 3        M6A        North York  Lawrence Manor, Lawrence Heights
# 4        M7A      Queen's Park     Ontario Provincial Government

# %% [markdown]
# <h3>Join the Tronto neighborhood dataset with the Tronto Geospatial Coord dataset</h3>

# %%
#Join the two DFs
Tron_Combined = Tron_neighborhoods.set_index('PostalCode').join(Tronto_GeoData_File.set_index('PostalCode'))
Tron_Combined

#Save joint DF as csv file
#df_csv = df.to_csv('Joined_DB_save_as.csv')
# Out:
#                           Borough  \
# PostalCode
# M3A                    North York
# M4A                    North York
# M5A              Downtown Toronto
# M6A                    North York
# M7A                  Queen's Park
# ...                           ...
# M8X                     Etobicoke
# M4Y              Downtown Toronto
# M7Y         East Toronto Business
# M8Y                     Etobicoke
# M8Z                     Etobicoke
#
#                                                  Neighborhood   Latitude  \
# PostalCode
# M3A                                                 Parkwoods  43.753259
# M4A                                          Victoria Village  43.725882
# M5A                                 Regent Park, Harbourfront  43.654260
# M6A                          Lawrence Manor, Lawrence Heights  43.718518
# M7A                             Ontario Provincial Government  43.662301
# ...                                                       ...        ...
# ...
